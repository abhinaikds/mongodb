# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pymongo.mongo_client import MongoClient

# %%
uri = "mongodb+srv://abhinaikds:Toshiba1234$@cluster0.mzrdjnu.mongodb.net/?retryWrites=true&w=majority&appName=AtlasApp"

# Create a new client and connect to the server
client = MongoClient(uri)

# %%
# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
mydb=client["mydatabase"]

# %%
client.list_database_names()
# Out:
# ['admin', 'local']

# %%
mycol=mydb["mycollection"]

# %%
myfirstrecord={"fname":"Sunny","sname":"savita","city":"bengaluru"}

# %%
mycol.insert_one(myfirstrecord)

# %%
mysecondrecord={"fname":"krish","sname":"naik","city":"bengaluru urban"}

# %%
mycol.insert_one(mysecondrecord)

# %%
mythirdrecord={"fname":"krish","sname":"naik","city":"bengaluru urban","salary":"10000"}

# %%
mycol.insert_one(mythirdrecord)

# %%
multiplerecord=[
{"fname":"abhi","sname":"naik","city":"bengaluru urban","salary":"5000"},
{"fname":"ashwin","sname":"naik","city":"bengaluru urban","salary":"6545"},
{"fname":"ansih","sname":"tk","city":"bengaluru urban","salary":"6546"},
{"fname":"ashwath","sname":"rai","city":"bengaluru urban","salary":"6545"}
]

# %%
mycol.insert_many(multiplerecord)
# Out:
# ---------------------------------------------------------------------------
# BulkWriteError                            Traceback (most recent call last)
# d:\Ineuron\MongoDB\demo.ipynb Cell 15 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/Ineuron/MongoDB/demo.ipynb#X30sZmlsZQ%3D%3D?line=0'>1</a> mycol.insert_many(multiplerecord)
#
# File d:\Ineuron\MongoDB\venv\lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File d:\Ineuron\MongoDB\venv\lib\site-packages\pymongo\collection.py:757, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     755 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     756 blk.ops = list(gen())
# --> 757 blk.execute(write_concern, session=session)
# ...

# %%
multiplerecords=[
{"_id":2,"fname":"qweww","sname":"tk","city":"bengaluru urban","salary":"6546"},
{"_id":3,"fname":"wewe","sname":"rai","city":"bengaluru urban","salary":"6545"}
]

# %%
mycol.insert_many(multiplerecords)

# %%
mycol.find_one()
# Out:
# {'_id': ObjectId('65379a6dc1808b5dd796c0a6'),
#  'fname': 'Sunny',
#  'sname': 'savita',
#  'city': 'bengaluru'}

# %%
mycol.find()

# %%
for i in mycol.find():
    print(i)
# Out:
# {'_id': ObjectId('65379a6dc1808b5dd796c0a6'), 'fname': 'Sunny', 'sname': 'savita', 'city': 'bengaluru'}
# {'_id': ObjectId('65379b83c1808b5dd796c0a7'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban'}
# {'_id': ObjectId('65379c65c1808b5dd796c0a8'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '10000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0a9'), 'fname': 'abhi', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '5000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0aa'), 'fname': 'ashwin', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ab'), 'fname': 'ansih', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ac'), 'fname': 'ashwath', 'sname': 'rai', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': 1, 'fname': 'sdc', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# ...

# %%
mycol.find_one({"fname":"ashwath"})
# Out:
# {'_id': ObjectId('65379f7cc1808b5dd796c0ac'),
#  'fname': 'ashwath',
#  'sname': 'rai',
#  'city': 'bengaluru urban',
#  'salary': '6545'}

# %%
mycol.find_one()

# %%
for i in mycol.find({"city":"bengaluru urban"}):
    print(i)
# Out:
# {'_id': ObjectId('65379b83c1808b5dd796c0a7'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban'}
# {'_id': ObjectId('65379c65c1808b5dd796c0a8'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '10000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0a9'), 'fname': 'abhi', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '5000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0aa'), 'fname': 'ashwin', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ab'), 'fname': 'ansih', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ac'), 'fname': 'ashwath', 'sname': 'rai', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': 1, 'fname': 'sdc', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': 2, 'fname': 'qweww', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# ...

# %%
mycol.find().sort("fname")

# %%
for i in mycol.find().sort("fname"):
    print(i)
# Out:
# {'_id': ObjectId('65379a6dc1808b5dd796c0a6'), 'fname': 'Sunny', 'sname': 'savita', 'city': 'bengaluru'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0a9'), 'fname': 'abhi', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '5000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ab'), 'fname': 'ansih', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ac'), 'fname': 'ashwath', 'sname': 'rai', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0aa'), 'fname': 'ashwin', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': ObjectId('65379b83c1808b5dd796c0a7'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban'}
# {'_id': ObjectId('65379c65c1808b5dd796c0a8'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '10000'}
# {'_id': 2, 'fname': 'qweww', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# ...

# %%
for i in mycol.find().sort("fname",-1):
    print(i)
# Out:
# {'_id': 3, 'fname': 'wewe', 'sname': 'rai', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': 1, 'fname': 'sdc', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': 2, 'fname': 'qweww', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': ObjectId('65379b83c1808b5dd796c0a7'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban'}
# {'_id': ObjectId('65379c65c1808b5dd796c0a8'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '10000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0aa'), 'fname': 'ashwin', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ac'), 'fname': 'ashwath', 'sname': 'rai', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ab'), 'fname': 'ansih', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# ...

# %%
mycol.delete_one({"fname":"wewe"})

# %%
for i in mycol.find():
    print(i)
# Out:
# {'_id': ObjectId('65379a6dc1808b5dd796c0a6'), 'fname': 'Sunny', 'sname': 'savita', 'city': 'bengaluru'}
# {'_id': ObjectId('65379b83c1808b5dd796c0a7'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban'}
# {'_id': ObjectId('65379c65c1808b5dd796c0a8'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '10000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0a9'), 'fname': 'abhi', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '5000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ab'), 'fname': 'ansih', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ac'), 'fname': 'ashwath', 'sname': 'rai', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': 1, 'fname': 'sdc', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': 2, 'fname': 'qweww', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}

# %%
mycol.delete_one({'city': 'bengaluru urban', 'salary': '6545'})

# %%
for i in mycol.find().limit(3):
    print(i)
# Out:
# {'_id': ObjectId('65379a6dc1808b5dd796c0a6'), 'fname': 'Sunny', 'sname': 'savita', 'city': 'bengaluru'}
# {'_id': ObjectId('65379b83c1808b5dd796c0a7'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban'}
# {'_id': ObjectId('65379c65c1808b5dd796c0a8'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '10000'}

# %%
myquery={"fname":"Mohit"}
newvalue={"$set":{"fname":"mohit"}}

# %%
mycol.update_one(myquery,newvalue)

# %%
for i in mycol.find():
    print(i)
# Out:
# {'_id': ObjectId('65379a6dc1808b5dd796c0a6'), 'fname': 'mohit', 'sname': 'bhargav', 'city': 'bengaluru', 'lname': 'bhargav'}
# {'_id': ObjectId('65379b83c1808b5dd796c0a7'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban'}
# {'_id': ObjectId('65379c65c1808b5dd796c0a8'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '10000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0a9'), 'fname': 'abhi', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '5000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ab'), 'fname': 'ansih', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ac'), 'fname': 'ashwath', 'sname': 'rai', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': 1, 'fname': 'sdc', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': 2, 'fname': 'qweww', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}

# %%
mycol.update_one({"sname":"savita"},{"$set":{"sname":"bhargav"}})

# %%
for i in mycol.find({"salary":{"$lt":5000}}):
    print(i)

# %%
for i in mycol.find():
    print(i)
# Out:
# {'_id': ObjectId('65379a6dc1808b5dd796c0a6'), 'fname': 'mohit', 'sname': 'bhargav', 'city': 'bengaluru', 'lname': 'bhargav'}
# {'_id': ObjectId('65379b83c1808b5dd796c0a7'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban'}
# {'_id': ObjectId('65379c65c1808b5dd796c0a8'), 'fname': 'krish', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '10000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0a9'), 'fname': 'abhi', 'sname': 'naik', 'city': 'bengaluru urban', 'salary': '5000'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ab'), 'fname': 'ansih', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': ObjectId('65379f7cc1808b5dd796c0ac'), 'fname': 'ashwath', 'sname': 'rai', 'city': 'bengaluru urban', 'salary': '6545'}
# {'_id': 1, 'fname': 'sdc', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}
# {'_id': 2, 'fname': 'qweww', 'sname': 'tk', 'city': 'bengaluru urban', 'salary': '6546'}

# %%
import pandas as pd

# %%
df=pd.read_csv("D:\Dataset\googleplaystore.csv")

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
len(df)
# Out:
# 10841

# %%
mycol2=mydb["googleplaystore"]

# %%
import json

# %%
json.loads(df.T.to_json())
# Out:
# {'0': {'App': 'Photo Editor & Candy Camera & Grid & ScrapBook',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.1,
#   'Reviews': '159',
#   'Size': '19M',
#   'Installs': '10,000+',
#   'Type': 'Free',
#   'Price': '0',
#   'Content Rating': 'Everyone',
#   'Genres': 'Art & Design',
#   'Last Updated': '7-Jan-18',
#   'Current Ver': '1.0.0',
#   'Android Ver': '4.0.3 and up'},
#  '1': {'App': 'Coloring book moana',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 3.9,
#   'Reviews': '967',
#   'Size': '14M',
#   'Installs': '500,000+',
#   'Type': 'Free',
#   'Price': '0',
#   'Content Rating': 'Everyone',
#   'Genres': 'Art & Design;Pretend Play',
#   'Last Updated': '15-Jan-18',
#   'Current Ver': '2.0.0',
#   'Android Ver': '4.0.3 and up'},
#  '2': {'App': 'U Launcher Lite – FREE Live Cool Themes, Hide Apps',
#   'Category': 'ART_AND_DESIGN',
#   'Rating': 4.7,
#   'Reviews': '87510',
#   'Size': '8.7M',
#   'Installs': '5,000,000+',
#   'Type': 'Free',
#   'Price': '0',
# ...

# %%
mycsv=list(json.loads(df.T.to_json()).values())

# %%
mycol2.insert_many(mycsv)
